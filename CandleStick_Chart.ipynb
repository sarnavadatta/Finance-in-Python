# %% [markdown]
# <a href="https://colab.research.google.com/github/sarnavadatta/Finance-in-Python/blob/main/CandleStick_Chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mplfinance
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 2.1 MB/s eta 0:00:00
# ...

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import mplfinance as mpf

# %%
# Download historical data for MSFT
start= dt.datetime(2024,1,1)
end= dt.datetime.now()
df = yf.download("MSFT",start,end)
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-02  373.859985  375.899994  366.769989  370.869995  369.518921
# 2024-01-03  369.010010  373.260010  368.510010  370.600006  369.249908
# 2024-01-04  370.670013  373.100006  367.170013  367.940002  366.599579
# 2024-01-05  368.970001  372.059998  366.500000  367.750000  366.410309
# 2024-01-08  369.299988  375.200012  369.010010  374.690002  373.325012
# ...                ...         ...         ...         ...         ...
# 2024-06-20  446.299988  446.529999  441.269989  445.700012  445.700012
# 2024-06-21  447.380005  450.579987  446.510010  449.779999  449.779999
# 2024-06-24  449.799988  452.750000  446.410004  447.670013  447.670013
# 2024-06-25  448.250000  451.420013  446.750000  450.950012  450.950012
# 2024-06-26  449.000000  453.600006  448.190002  452.160004  452.160004
#
#               Volume
# Date
# ...

# %%
# Plot the stock price chart
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.title("Microsoft stock price")
plt.xlabel("Date")
plt.ylabel("Price")
plt.plot(df.index, df["Close"], label="Close")
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
# '''
# We select the columns Open, High, Low, Close, and Volume from the DataFrame.
# We set the index name to “Date” and convert the “Date” column to the datetime format.
# Finally, we set the “Date” column as the index of the DataFrame.
# '''
# df = df[['Open','High', 'Low', 'Close','Volume']] # Select required columns
# df.index.name = 'Date' # Set the index name
# df = df.reset_index() # Reset the index
# df['Date'] = pd.to_datetime(df['Date']) # Convert the Date column to datetime format
# df = df.set_index('Date') # Set the Date column as the index
# df

# %%
# prompt: plot the candlestick chart of df using mpl-finance library

import mplfinance as mpf


mpf.plot(df, type='candle', title='Candlestick Chart for MSFT', ylabel='Price', style='yahoo')
mpf.show()
