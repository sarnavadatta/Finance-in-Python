# %% [markdown]
# <a href="https://colab.research.google.com/github/sarnavadatta/Finance-in-Python/blob/main/Get_Financial_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bajaj Finance Stock Analysis
#
# ## Project Overview and Purpose
#
# This project aims to perform a comprehensive analysis of Bajaj Finance Limited's stock (BAJFINANCE.NS) using Python and the `yfinance` library.
# The primary goal is to evaluate the stock's performance, financial health, and risks to provide insights for investment decisions.
#
# ## Dataset Description and Source
#
# The project uses historical stock price data and financial data obtained using the `yfinance` library, which sources data from Yahoo Finance.
# This data includes daily stock prices for the past 5 years, financial statements, key ratios, and company information.
#
# ## Methodology and Approach
#
# The analysis involves the following steps:
# 1. **Data Retrieval:** Download historical stock price and financial data using `yfinance`.
# 2. **Financial Ratios Calculation:** Calculate key financial ratios like P/E, ROE, ROCE, Debt-to-Equity, etc., using retrieved data.
# 3. **Risk and Return Analysis:** Compute Alpha, Beta, Sharpe ratio, annualized return, and volatility to understand risk and return characteristics.
# 4. **Visualization (Optional):** Create visualizations (not implemented in the current code) to illustrate key findings.
#
# ## Code Structure and Usage
# - The code is structured into several sections, starting with data retrieval, then analysis of financial indicators, and finally, risk & return calculations.
# - Each section clearly defines its purpose with comments.
# - To use the code, replace the stock ticker (`BAJFINANCE.NS`) with any other valid stock symbol if needed.
#
# ## Results and Visualizations
#
# - The code outputs calculated financial ratios, risk & return metrics in the console.
# - Visualizations for trend analysis and key metrics can be added (suggested as future work).
#
# ## Future Work and Improvements
#
# - Incorporate data visualization using `matplotlib` or `seaborn` to present findings effectively.
# - Expand analysis to include technical indicators (moving averages, RSI, etc.).
# - Develop an interactive dashboard for better user experience and visualization.
# - Implement a comparative analysis with competitors' stocks.

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from datetime import datetime, timedelta

# %% [markdown]
# **Get the stock data for Bajaj finance**

# %%
stockdata = yf.download(tickers='BAJFINANCE.NS', period='5y', interval='1d')
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
stockdata.head()
# Out:
# Price              Close          High           Low          Open  \
# Ticker     BAJFINANCE.NS BAJFINANCE.NS BAJFINANCE.NS BAJFINANCE.NS
# Date
# 2020-04-13   2254.380371   2483.731218   2233.337552   2483.731218
# 2020-04-15   2151.039551   2333.919114   2137.191714   2311.250136
# 2020-04-16   2188.049316   2217.617550   2091.459752   2114.128731
# 2020-04-17   2274.930420   2341.705345   2203.030383   2321.106239
# 2020-04-20   2275.029297   2311.743189   2232.401758   2291.538228
#
# Price             Volume
# Ticker     BAJFINANCE.NS
# Date
# 2020-04-13       8183199
# 2020-04-15       9333628
# 2020-04-16       7246740
# 2020-04-17      10191546
# 2020-04-20       5403177

# %% [markdown]
# **Get Financial data of the stock**

# %%
Bajaj_finance = yf.Ticker('BAJFINANCE.NS')

# %% [markdown]
# **Getting the balace sheet**

# %%
Bajaj_finance.balance_sheet
# Out:
#                                                          2024-03-31  \
# Treasury Shares Number                                     988329.0
# Ordinary Shares Number                                  618007991.0
# Share Issued                                            618996320.0
# Net Debt                                            2100691200000.0
# Total Debt                                          2184371100000.0
# Tangible Book Value                                  757856600000.0
# Invested Capital                                    2941313000000.0
# Net Tangible Assets                                  757856600000.0
# Common Stock Equity                                  766953500000.0
# Total Capitalization                                2941313000000.0
# Total Equity Gross Minority Interest                 766953500000.0
# Stockholders Equity                                  766953500000.0
# Other Equity Interest                                 10085100000.0
# Retained Earnings                                    370804100000.0
# Additional Paid In Capital                           265820000000.0
# Capital Stock                                          1238000000.0
# Common Stock                                           1238000000.0
# Total Liabilities Net Minority Interest             2990462700000.0
# Derivative Product Liabilities                           21200000.0
# Long Term Debt And Capital Lease Obligation         2184371100000.0
# Payables                                              34820800000.0
# Other Payable                                         13063300000.0
# Dividends Payable                                        30700000.0
# Total Tax Payable                                      1086400000.0
# Accounts Payable                                      20640400000.0
# Total Assets                                        3757416200000.0
# Investments And Advances                             100270700000.0
# Investmentin Financial Assets                         96576500000.0
# Available For Sale Securities                         46739300000.0
# Financial Assets Designatedas Fair Value Throug...    49558800000.0
# Long Term Equity Investment                            3694200000.0
# Investmentsin Associatesat Cost                        3694200000.0
# Goodwill And Other Intangible Assets                   9096900000.0
# Other Intangible Assets                                9064200000.0
# Goodwill                                                 32700000.0
# Net PPE                                               23836700000.0
# Accumulated Depreciation                             -14428600000.0
# Gross PPE                                             38265300000.0
# Construction In Progress                                253500000.0
# Other Properties                                       4106400000.0
# Machinery Furniture Equipment                         12051600000.0
# Buildings And Improvements                            19120700000.0
# Land And Improvements                                  2733100000.0
# Prepaid Assets                                         3852000000.0
# Receivables                                           22881100000.0
# Taxes Receivable                                       2909200000.0
# Cash And Cash Equivalents                             73668300000.0
# Cash Financial                                          588400000.0
# Cash Cash Equivalents And Federal Funds Sold         107994500000.0
#
#                                                          2023-03-31  \
# Treasury Shares Number                                    1008401.0
# Ordinary Shares Number                                  604420832.0
# Share Issued                                            605429233.0
# Net Debt                                            1611463200000.0
# Total Debt                                          1644669400000.0
# Tangible Book Value                                  536756900000.0
# Invested Capital                                    2182515500000.0
# Net Tangible Assets                                  536756900000.0
# Common Stock Equity                                  543719800000.0
# Total Capitalization                                2182515500000.0
# Total Equity Gross Minority Interest                 543719800000.0
# Stockholders Equity                                  543719800000.0
# Other Equity Interest                                  5552600000.0
# Retained Earnings                                    273208900000.0
# Additional Paid In Capital                           174409800000.0
# Capital Stock                                          1210900000.0
# Common Stock                                           1210900000.0
# Total Liabilities Net Minority Interest             2208543300000.0
# Derivative Product Liabilities                           40100000.0
# Long Term Debt And Capital Lease Obligation         1644669400000.0
# Payables                                              26030700000.0
# Other Payable                                         10094900000.0
# Dividends Payable                                        22500000.0
# Total Tax Payable                                      1392100000.0
# Accounts Payable                                      14521200000.0
# Total Assets                                        2752263100000.0
# Investments And Advances                              94522100000.0
# Investmentin Financial Assets                         93578100000.0
# Available For Sale Securities                         26853000000.0
# Financial Assets Designatedas Fair Value Throug...    65236300000.0
# Long Term Equity Investment                             944000000.0
# Investmentsin Associatesat Cost                         944000000.0
# Goodwill And Other Intangible Assets                   6962900000.0
# Other Intangible Assets                                6930200000.0
# Goodwill                                                 32700000.0
# Net PPE                                               16911700000.0
# Accumulated Depreciation                             -11294900000.0
# Gross PPE                                             28206600000.0
# Construction In Progress                                146000000.0
# Other Properties                                       2771300000.0
# Machinery Furniture Equipment                          9247100000.0
# Buildings And Improvements                            13323100000.0
# Land And Improvements                                  2719100000.0
# Prepaid Assets                                         3414700000.0
# Receivables                                           16141100000.0
# Taxes Receivable                                       1814300000.0
# Cash And Cash Equivalents                             27332500000.0
# Cash Financial                                          590700000.0
# Cash Cash Equivalents And Federal Funds Sold          44939900000.0
#
#                                                          2022-03-31  \
# Treasury Shares Number                                    2149392.0
# Ordinary Shares Number                                  603279841.0
# Share Issued                                            605429233.0
# Net Debt                                            1286728900000.0
# Total Debt                                          1328883000000.0
# Tangible Book Value                                  432581000000.0
# Invested Capital                                    1761459300000.0
# Net Tangible Assets                                  432581000000.0
# Common Stock Equity                                  437126900000.0
# Total Capitalization                                1761459300000.0
# Total Equity Gross Minority Interest                 437126900000.0
# Stockholders Equity                                  437126900000.0
# Other Equity Interest                                  3971300000.0
# Retained Earnings                                    192519900000.0
# Additional Paid In Capital                           172177700000.0
# Capital Stock                                          1210900000.0
# Common Stock                                           1210900000.0
# Total Liabilities Net Minority Interest             1687931700000.0
# Derivative Product Liabilities                         1400200000.0
# Long Term Debt And Capital Lease Obligation         1328883000000.0
# Payables                                              21256600000.0
# Other Payable                                          8663500000.0
# Dividends Payable                                        17900000.0
# Total Tax Payable                                      1000600000.0
# Accounts Payable                                      11574600000.0
# Total Assets                                        2125058600000.0
# Investments And Advances                              54125100000.0
# Investmentin Financial Assets                         54125100000.0
# Available For Sale Securities                         38272600000.0
# Financial Assets Designatedas Fair Value Throug...    14633500000.0
# Long Term Equity Investment                                     0.0
# Investmentsin Associatesat Cost                                 0.0
# Goodwill And Other Intangible Assets                   4545900000.0
# Other Intangible Assets                                4513200000.0
# Goodwill                                                 32700000.0
# Net PPE                                               12958500000.0
# Accumulated Depreciation                              -9037100000.0
# Gross PPE                                             21995600000.0
# Construction In Progress                                132700000.0
# Other Properties                                       1733500000.0
# Machinery Furniture Equipment                          7360600000.0
# Buildings And Improvements                            10802900000.0
# Land And Improvements                                  1965900000.0
# Prepaid Assets                                         2503700000.0
# Receivables                                           14987400000.0
# Taxes Receivable                                       1683000000.0
# Cash And Cash Equivalents                             37603500000.0
# Cash Financial                                          537200000.0
# Cash Cash Equivalents And Federal Funds Sold          71333200000.0
#
#                                                          2021-03-31
# Treasury Shares Number                                          NaN
# Ordinary Shares Number                                  602587339.0
# Share Issued                                            602587339.0
# Net Debt                                            1032860000000.0
# Total Debt                                          1058739500000.0
# Tangible Book Value                                  366004100000.0
# Invested Capital                                    1424485500000.0
# Net Tangible Assets                                  366004100000.0
# Common Stock Equity                                  369184100000.0
# Total Capitalization                                1424485500000.0
# Total Equity Gross Minority Interest                 369184100000.0
# Stockholders Equity                                  369184100000.0
# Other Equity Interest                                  3030500000.0
# Retained Earnings                                    142428400000.0
# Additional Paid In Capital                           169784500000.0
# Capital Stock                                          1205200000.0
# Common Stock                                           1205200000.0
# Total Liabilities Net Minority Interest             1345519900000.0
# Derivative Product Liabilities                         1378700000.0
# Long Term Debt And Capital Lease Obligation         1058739500000.0
# Payables                                              16712400000.0
# Other Payable                                          6047100000.0
# Dividends Payable                                        20800000.0
# Total Tax Payable                                      1801700000.0
# Accounts Payable                                       8842800000.0
# Total Assets                                        1714704000000.0
# Investments And Advances                             145181500000.0
# Investmentin Financial Assets                        145181500000.0
# Available For Sale Securities                         14818400000.0
# Financial Assets Designatedas Fair Value Throug...   130363100000.0
# Long Term Equity Investment                                     NaN
# Investmentsin Associatesat Cost                                 NaN
# Goodwill And Other Intangible Assets                   3180000000.0
# Other Intangible Assets                                3147300000.0
# Goodwill                                                 32700000.0
# Net PPE                                               10487600000.0
# Accumulated Depreciation                              -7180000000.0
# Gross PPE                                             17667600000.0
# Construction In Progress                                 70700000.0
# Other Properties                                       1295200000.0
# Machinery Furniture Equipment                          6748000000.0
# Buildings And Improvements                             8499000000.0
# Land And Improvements                                  1054700000.0
# Prepaid Assets                                         1890300000.0
# Receivables                                           14111600000.0
# Taxes Receivable                                       1597700000.0
# Cash And Cash Equivalents                             22441400000.0
# Cash Financial                                          568400000.0
# Cash Cash Equivalents And Federal Funds Sold          25021600000.0

# %% [markdown]
# **Retrieve Income Statement**

# %%
Bajaj_finance.get_financials()
# Out:
#                                                         2024-03-31  \
# TaxEffectOfUnusualItems                               -237947577.0
# TaxRateForCalcs                                            0.25161
# TotalUnusualItems                                     -945700000.0
# TotalUnusualItemsExcludingGoodwill                    -945700000.0
# NetIncomeFromContinuingOperationNetMinorityInte...  144511700000.0
# ReconciledDepreciation                                6833200000.0
# NetInterestIncome                                   295819200000.0
# InterestExpense                                     187246900000.0
# InterestIncome                                      483066100000.0
# NormalizedIncome                                    145219452423.0
# NetIncomeFromContinuingAndDiscontinuedOperation     144511700000.0
# DilutedAverageShares                                   612383049.0
# BasicAverageShares                                     610032743.0
# DilutedEPS                                                  235.98
# BasicEPS                                                    236.89
# DilutedNIAvailtoComStockholders                     144511700000.0
# NetIncomeCommonStockholders                         144511700000.0
# NetIncome                                           144511700000.0
# NetIncomeIncludingNoncontrollingInterests           144511700000.0
# NetIncomeContinuousOperations                       144511700000.0
# TaxProvision                                         48584000000.0
# PretaxIncome                                        193095700000.0
# SpecialIncomeCharges                                  -945700000.0
# OtherSpecialCharges                                    125400000.0
# WriteOff                                               820300000.0
# GainOnSaleOfSecurity                                  3296100000.0
# OperatingExpense                                    103811500000.0
# OtherOperatingExpenses                               27102900000.0
# DepreciationAndAmortizationInIncomeStatement          6833200000.0
# DepreciationIncomeStatement                           6833200000.0
# SellingGeneralAndAdministration                       4027700000.0
# SellingAndMarketingExpense                            3491800000.0
# GeneralAndAdministrativeExpense                        535900000.0
# InsuranceAndClaims                                      81900000.0
# RentAndLandingFees                                     749200000.0
# TotalRevenue                                        343263200000.0
# OperatingRevenue                                    343263200000.0
#
#                                                         2023-03-31  \
# TaxEffectOfUnusualItems                               -161708940.0
# TaxRateForCalcs                                             0.2589
# TotalUnusualItems                                     -624600000.0
# TotalUnusualItemsExcludingGoodwill                    -624600000.0
# NetIncomeFromContinuingOperationNetMinorityInte...  115076900000.0
# ReconciledDepreciation                                4853800000.0
# NetInterestIncome                                   229890600000.0
# InterestExpense                                     125598900000.0
# InterestIncome                                      355489500000.0
# NormalizedIncome                                    115539791060.0
# NetIncomeFromContinuingAndDiscontinuedOperation     115076900000.0
# DilutedAverageShares                                   607044727.0
# BasicAverageShares                                     603976750.0
# DilutedEPS                                                  189.57
# BasicEPS                                                    190.53
# DilutedNIAvailtoComStockholders                     115076900000.0
# NetIncomeCommonStockholders                         115076900000.0
# NetIncome                                           115076900000.0
# NetIncomeIncludingNoncontrollingInterests           115076900000.0
# NetIncomeContinuousOperations                       115076900000.0
# TaxProvision                                         40201700000.0
# PretaxIncome                                        155278600000.0
# SpecialIncomeCharges                                  -624600000.0
# OtherSpecialCharges                                    133300000.0
# WriteOff                                               491300000.0
# GainOnSaleOfSecurity                                  3290600000.0
# OperatingExpense                                     82377300000.0
# OtherOperatingExpenses                               21227400000.0
# DepreciationAndAmortizationInIncomeStatement          4853800000.0
# DepreciationIncomeStatement                           4853800000.0
# SellingGeneralAndAdministration                       3913600000.0
# SellingAndMarketingExpense                            3619900000.0
# GeneralAndAdministrativeExpense                        293700000.0
# InsuranceAndClaims                                      62600000.0
# RentAndLandingFees                                     568300000.0
# TotalRevenue                                        269669000000.0
# OperatingRevenue                                    269669000000.0
#
#                                                         2022-03-31  \
# TaxEffectOfUnusualItems                                -66891264.0
# TaxRateForCalcs                                            0.26048
# TotalUnusualItems                                     -256800000.0
# TotalUnusualItemsExcludingGoodwill                    -256800000.0
# NetIncomeFromContinuingOperationNetMinorityInte...   70282300000.0
# ReconciledDepreciation                                3845700000.0
# NetInterestIncome                                   175236400000.0
# InterestExpense                                      97537000000.0
# InterestIncome                                      272773400000.0
# NormalizedIncome                                     70472208736.0
# NetIncomeFromContinuingAndDiscontinuedOperation      70282300000.0
# DilutedAverageShares                                   606966459.0
# BasicAverageShares                                     602574303.0
# DilutedEPS                                                  115.79
# BasicEPS                                                    116.64
# DilutedNIAvailtoComStockholders                      70282300000.0
# NetIncomeCommonStockholders                          70282300000.0
# NetIncome                                            70282300000.0
# NetIncomeIncludingNoncontrollingInterests            70282300000.0
# NetIncomeContinuousOperations                        70282300000.0
# TaxProvision                                         24755500000.0
# PretaxIncome                                         95037800000.0
# SpecialIncomeCharges                                  -256800000.0
# OtherSpecialCharges                                    248400000.0
# WriteOff                                                 8400000.0
# GainOnSaleOfSecurity                                  3277300000.0
# OperatingExpense                                     58001900000.0
# OtherOperatingExpenses                               15258200000.0
# DepreciationAndAmortizationInIncomeStatement          3845700000.0
# DepreciationIncomeStatement                           3845700000.0
# SellingGeneralAndAdministration                       2014400000.0
# SellingAndMarketingExpense                            1764300000.0
# GeneralAndAdministrativeExpense                        250100000.0
# InsuranceAndClaims                                      59900000.0
# RentAndLandingFees                                     501800000.0
# TotalRevenue                                        201322100000.0
# OperatingRevenue                                    201322100000.0
#
#                                                         2021-03-31
# TaxEffectOfUnusualItems                                -86460800.0
# TaxRateForCalcs                                             0.2624
# TotalUnusualItems                                     -329500000.0
# TotalUnusualItemsExcludingGoodwill                    -329500000.0
# NetIncomeFromContinuingOperationNetMinorityInte...   44198200000.0
# ReconciledDepreciation                                3252700000.0
# NetInterestIncome                                   138941500000.0
# InterestExpense                                      94140000000.0
# InterestIncome                                      233081500000.0
# NormalizedIncome                                     44441239200.0
# NetIncomeFromContinuingAndDiscontinuedOperation      44198200000.0
# DilutedAverageShares                                   605495861.0
# BasicAverageShares                                     600670592.0
# DilutedEPS                                                    73.0
# BasicEPS                                                     73.58
# DilutedNIAvailtoComStockholders                      44198200000.0
# NetIncomeCommonStockholders                          44198200000.0
# NetIncome                                            44198200000.0
# NetIncomeIncludingNoncontrollingInterests            44198200000.0
# NetIncomeContinuousOperations                        44198200000.0
# TaxProvision                                         15724400000.0
# PretaxIncome                                         59922600000.0
# SpecialIncomeCharges                                  -329500000.0
# OtherSpecialCharges                                     68500000.0
# WriteOff                                               261000000.0
# GainOnSaleOfSecurity                                  5912200000.0
# OperatingExpense                                     40548800000.0
# OtherOperatingExpenses                               10636000000.0
# DepreciationAndAmortizationInIncomeStatement          3252700000.0
# DepreciationIncomeStatement                           3252700000.0
# SellingGeneralAndAdministration                       1229000000.0
# SellingAndMarketingExpense                            1041600000.0
# GeneralAndAdministrativeExpense                        187400000.0
# InsuranceAndClaims                                      52500000.0
# RentAndLandingFees                                     354400000.0
# TotalRevenue                                        160225700000.0
# OperatingRevenue                                    160225700000.0

# %% [markdown]
# **Get Financial news of the company**

# %%
Bajaj_finance.get_news()
# Out:
# [{'id': 'e349a55b-3345-32f5-a7d6-710befb8c7b3',
#   'content': {'id': 'e349a55b-3345-32f5-a7d6-710befb8c7b3',
#    'contentType': 'STORY',
#    'title': "India's Bajaj Finance extends rally to record high on 'smooth' top management succession",
#    'description': '',
#    'summary': 'The non-banking financial company also announced present deputy MD Anup Kumar Saha will be replacing Rajeev Jain as MD.  "The move should allow Jain to stay involved in short- and mid-range planning at Bajaj Finance and investor engagements," Jefferies said in a note.  Smooth succession, healthy growth and improving asset quality will aid valuations, the brokerage said, adding that Bajaj Finance remains a top pick.',
#    'pubDate': '2025-03-21T04:12:02Z',
#    'displayTime': '2025-03-21T04:12:02Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': None,
#    'provider': {'displayName': 'Reuters', 'url': 'https://www.reuters.com/'},
#    'canonicalUrl': {'url': 'https://sg.finance.yahoo.com/news/indias-bajaj-finance-extends-rally-041202882.html',
#     'site': 'finance',
#     'region': 'SG',
#     'lang': 'en-SG'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/indias-bajaj-finance-extends-rally-041202882.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': 'f7fe3fb0-ff48-3825-94c2-f37604868a09',
#   'content': {'id': 'f7fe3fb0-ff48-3825-94c2-f37604868a09',
#    'contentType': 'STORY',
#    'title': 'Financial Services Roundup: Market Talk',
#    'description': '',
#    'summary': 'Find insight on auto insurers, Allstate, Bajaj Finance and more in the latest Market Talks covering Financial Services.',
#    'pubDate': '2025-01-31T21:54:00Z',
#    'displayTime': '2025-01-31T21:54:00Z',
#    'isHosted': False,
#    'bypassModal': False,
#    'previewUrl': 'https://finance.yahoo.com/m/f7fe3fb0-ff48-3825-94c2-f37604868a09/financial-services-roundup-.html',
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/wsj.com/7b2c285183be07ca3c4e8242b25a59a8',
#     'originalWidth': 1200,
#     'originalHeight': 630,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/Fwf5HL4GsEGPbDfR3MJBPg--~B/aD02MzA7dz0xMjAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/wsj.com/7b2c285183be07ca3c4e8242b25a59a8',
#       'width': 1200,
#       'height': 630,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/c34MZxHLZOfDYN2BBjM9ww--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/wsj.com/7b2c285183be07ca3c4e8242b25a59a8',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'The Wall Street Journal',
#     'url': 'http://www.wsj.com/'},
#    'canonicalUrl': {'url': 'https://www.wsj.com/finance/banking/financial-services-roundup-market-talk-285171ab?siteid=yhoof2&yptr=yahoo',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': None,
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '46062e20-295b-326d-b8d8-070ccdd3b826',
#   'content': {'id': '46062e20-295b-326d-b8d8-070ccdd3b826',
#    'contentType': 'STORY',
#    'title': 'Bajaj Finance Ltd (BOM:500034) Q3 2025 Earnings Call Highlights: Record AUM Growth and ...',
#    'description': '',
#    'summary': 'Despite challenges in asset quality, Bajaj Finance Ltd (BOM:500034) showcases robust growth and strategic initiatives to enhance its market position.',
#    'pubDate': '2025-01-31T07:15:48Z',
#    'displayTime': '2025-01-31T07:15:48Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': None,
#    'provider': {'displayName': 'GuruFocus.com',
#     'url': 'http://www.gurufocus.com/'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/bajaj-finance-ltd-bom-500034-071548491.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/bajaj-finance-ltd-bom-500034-071548491.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '1245a4ac-6a96-3a76-8041-5fa5e4e5c7bd',
#   'content': {'id': '1245a4ac-6a96-3a76-8041-5fa5e4e5c7bd',
#    'contentType': 'STORY',
#    'title': "India's Bajaj Finance jumps to record as strong Q3 earnings light up growth path",
#    'description': '',
#    'summary': 'Bajaj Finance and its holding company Bajaj Finserv, trading higher by 2.6% and 1.3%, respectively, were among the top gainers in India\'s benchmark Nifty 50 index, which was up 0.6% as of 10:33 a.m. IST.  At least 12 analysts raised their target prices for Bajaj Finance after the results, with the median price target rising to 8,500 rupees from 8,110 a month ago, according to data compiled by LSEG.  The performance has set the company up for strong earnings growth in 2025-2026, Morgan Stanley analysts said in a note, which makes the lender an "interesting large-cap in a tough market."',
#    'pubDate': '2025-01-30T05:23:00Z',
#    'displayTime': '2025-01-30T05:23:00Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/reuters.com/6357a71bd03a1dcc492661cf419a2049',
#     'originalWidth': 800,
#     'originalHeight': 534,
#     'caption': 'A logo of the NSE (National Stock Exchange) is seen on an office building at the Gujarat International Finance Tec-City (GIFT) at Gandhinagar',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/jgWwhYSMU_QVkwu8EUV9UQ--~B/aD01MzQ7dz04MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters.com/6357a71bd03a1dcc492661cf419a2049',
#       'width': 800,
#       'height': 534,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/SdhVilbzoeGSxdt.dit.dw--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters.com/6357a71bd03a1dcc492661cf419a2049',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Reuters', 'url': 'https://www.reuters.com/'},
#    'canonicalUrl': {'url': 'https://sg.finance.yahoo.com/news/indias-bajaj-finance-jumps-record-052300852.html',
#     'site': 'finance',
#     'region': 'SG',
#     'lang': 'en-SG'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/indias-bajaj-finance-jumps-record-052300852.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '4d819544-ed08-31a0-a4eb-d5d522436da1',
#   'content': {'id': '4d819544-ed08-31a0-a4eb-d5d522436da1',
#    'contentType': 'STORY',
#    'title': "India's Bharti Airtel to offer Bajaj Finance's loan products",
#    'description': '',
#    'summary': "Indian telecom major Bharti Airtel will be offering non-banking lender Bajaj Finance's financial products in the country, the companies said on Monday.  Airtel will initially offer Bajaj Finance's products through its application, and later via its physical stores, they said in a joint statement.  The partnership will enable Bajaj Finance, the country's largest private-sector non-banking financial company, to tap Airtel's 375 million customers.",
#    'pubDate': '2025-01-20T09:55:31Z',
#    'displayTime': '2025-01-20T13:16:59Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/reuters.com/5454ab5d383092eff8392b00b1e27160',
#     'originalWidth': 800,
#     'originalHeight': 514,
#     'caption': 'A man walks across a board showing the logo of Airtel at the ongoing India Mobile Congress 2022, at Pragati Maidan, in New Delhi',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/igYzrpr62yONo80cqMywQQ--~B/aD01MTQ7dz04MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters.com/5454ab5d383092eff8392b00b1e27160',
#       'width': 800,
#       'height': 514,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/9ioPlZqhzcEl8n0d5MBrcQ--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters.com/5454ab5d383092eff8392b00b1e27160',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Reuters', 'url': 'https://www.reuters.com/'},
#    'canonicalUrl': {'url': 'https://sg.finance.yahoo.com/news/indias-bharti-airtel-offer-bajaj-095531943.html',
#     'site': 'finance',
#     'region': 'SG',
#     'lang': 'en-SG'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/indias-bharti-airtel-offer-bajaj-095531943.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '3b5d9121-369a-3762-971c-e8d7598fdc06',
#   'content': {'id': '3b5d9121-369a-3762-971c-e8d7598fdc06',
#    'contentType': 'STORY',
#    'title': 'India’s RBL Bank and Bajaj end credit card tie-up',
#    'description': '',
#    'summary': 'The existing RBL-Bajaj co-branded credit cards will continue to function normally.',
#    'pubDate': '2024-12-02T16:26:36Z',
#    'displayTime': '2024-12-02T16:26:36Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/retail_banker_international_407/78d6a90f8e0a116c0b401c99b25ca440',
#     'originalWidth': 1439,
#     'originalHeight': 809,
#     'caption': 'RBL Bank will continue to focus on expanding its credit card segment. Credit: PradeepGaurs/Shutterstock.',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/qshmM4iHeqqItnxldWhqdA--~B/aD04MDk7dz0xNDM5O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/retail_banker_international_407/78d6a90f8e0a116c0b401c99b25ca440',
#       'width': 1439,
#       'height': 809,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/7C7LIjrnGuKQbfenErCJ3g--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/retail_banker_international_407/78d6a90f8e0a116c0b401c99b25ca440',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Retail Banker International',
#     'url': 'https://www.globaldata.com/'},
#    'canonicalUrl': {'url': 'https://www.retailbankerinternational.com/news/rbl-bajaj-end-credit/',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/india-rbl-bank-bajaj-end-162636056.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '05f17317-b6df-378f-8c48-068bdd3d11ff',
#   'content': {'id': '05f17317-b6df-378f-8c48-068bdd3d11ff',
#    'contentType': 'STORY',
#    'title': 'Bajaj Finance Ltd (BOM:500034) Q2 2025 Earnings Call Highlights: Strong AUM Growth and Customer ...',
#    'description': '',
#    'summary': 'Bajaj Finance Ltd (BOM:500034) reports robust growth in assets and customer base, while navigating challenges in loan losses and cost management.',
#    'pubDate': '2024-10-23T07:04:43Z',
#    'displayTime': '2024-10-23T07:04:43Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': None,
#    'provider': {'displayName': 'GuruFocus.com',
#     'url': 'http://www.gurufocus.com/'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/bajaj-finance-ltd-bom-500034-070443253.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/bajaj-finance-ltd-bom-500034-070443253.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '100f8014-d66f-310b-854d-bbc61cc3e7ef',
#   'content': {'id': '100f8014-d66f-310b-854d-bbc61cc3e7ef',
#    'contentType': 'STORY',
#    'title': 'Indian shares post worst week in over 2 years as Mideast fears, foreign outflows weigh',
#    'description': '',
#    'summary': '(Reuters) -Indian shares fell for a fifth session on Friday and posted their worst week in over two years as concerns about the deepening conflict in the Middle East continued to rattle investors, while rising foreign outflows also weighed.  The Nifty 50 index fell 0.93% to 25,014.6, while the S&P BSE Sensex shed 0.98% to 81,688.45, on the day.  The escalating Middle East conflict rang alarm bells that crude supplies from the top oil-producing region may be disrupted.',
#    'pubDate': '2024-10-04T02:55:46Z',
#    'displayTime': '2024-10-04T10:19:56Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/reuters.com/49692205c0a57b1a5ac2ae846465974f',
#     'originalWidth': 800,
#     'originalHeight': 546,
#     'caption': 'People gather inside the National Stock Exchange (NSE) in Mumbai',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/CzNYkpYktgW60vr...iStA--~B/aD01NDY7dz04MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters.com/49692205c0a57b1a5ac2ae846465974f',
#       'width': 800,
#       'height': 546,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/jBB6QW353DTeKwx3dvSsGg--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters.com/49692205c0a57b1a5ac2ae846465974f',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Reuters', 'url': 'https://www.reuters.com/'},
#    'canonicalUrl': {'url': 'https://sg.finance.yahoo.com/news/indian-shares-set-open-higher-025546524.html',
#     'site': 'finance',
#     'region': 'SG',
#     'lang': 'en-SG'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/indian-shares-set-open-higher-025546524.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '94b4f282-fd46-483c-ba5c-a0e26e8a8feb',
#   'content': {'id': '94b4f282-fd46-483c-ba5c-a0e26e8a8feb',
#    'contentType': 'STORY',
#    'title': 'Trending tickers: Palantir, Playtech, Intel and Bajaj Finance',
#    'description': '',
#    'summary': 'The latest investor updates on stocks that are trending on Monday.',
#    'pubDate': '2024-09-16T10:11:03Z',
#    'displayTime': '2024-09-16T10:11:03Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://s.yimg.com/os/creatr-uploaded-images/2024-06/0f710c80-2280-11ef-a7de-5195a036e843',
#     'originalWidth': 4000,
#     'originalHeight': 2615,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/HNrQQpSpOkLF2c_TTehDGw--~B/aD0yNjE1O3c9NDAwMDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2024-06/0f710c80-2280-11ef-a7de-5195a036e843',
#       'width': 4000,
#       'height': 2615,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/X1HUIgg2a2IJkJtKIVq_fw--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2024-06/0f710c80-2280-11ef-a7de-5195a036e843',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Yahoo Finance UK',
#     'url': 'http://uk.finance.yahoo.com/'},
#    'canonicalUrl': {'url': 'https://uk.finance.yahoo.com/news/palantir-playtech-intel-bajaj-finance-trending-tickers-101103113.html',
#     'site': 'finance',
#     'region': 'GB',
#     'lang': 'en-GB'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/palantir-playtech-intel-bajaj-finance-trending-tickers-101103113.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': 'c354bed3-d97d-3143-a3c2-d8a7d9f95d9b',
#   'content': {'id': 'c354bed3-d97d-3143-a3c2-d8a7d9f95d9b',
#    'contentType': 'STORY',
#    'title': 'Bajaj Housing Finance draws bids worth $39 billion in hottest India IPO this year',
#    'description': '',
#    'summary': "The interest in the company's public offer -- the most this year among mainboard IPOs worth more than $500 million -- was due to the lender's prospects in a booming home loan market and came during the busiest week for Indian IPOs in 2024.  Bajaj Housing Finance, a unit of non-bank lender Bajaj Finance, will become India's largest listed home loan financier, with its $782 million IPO valuing the company at $7 billion.",
#    'pubDate': '2024-09-11T13:27:33Z',
#    'displayTime': '2024-09-11T13:27:33Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/reuters.com/89faa3b84e76adfa0a8ddfff94b8678a',
#     'originalWidth': 800,
#     'originalHeight': 554,
#     'caption': 'A guard stands at the gate of the National Stock Exchange (NSE) in Mumbai',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/o1PBkn1BAFZwtH4jnb8O3w--~B/aD01NTQ7dz04MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters.com/89faa3b84e76adfa0a8ddfff94b8678a',
#       'width': 800,
#       'height': 554,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/7c8BqR4SYbBHdYH0SWCxFg--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters.com/89faa3b84e76adfa0a8ddfff94b8678a',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Reuters', 'url': 'https://www.reuters.com/'},
#    'canonicalUrl': {'url': 'https://sg.finance.yahoo.com/news/bajaj-housing-finance-draws-bids-132733408.html',
#     'site': 'finance',
#     'region': 'SG',
#     'lang': 'en-SG'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/bajaj-housing-finance-draws-bids-132733408.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}}]

# %%
Bajaj_finance.get_major_holders()
# Out:
# Breakdown                         Value
# insidersPercentHeld             0.54906
# institutionsPercentHeld         0.25211
# institutionsFloatPercentHeld    0.55908
# institutionsCount             283.00000

# %%
# Cash Flow Statement
Bajaj_finance.get_cash_flow()
# Out:
#                                              2024-03-31       2023-03-31  \
# FreeCashFlow                            -737979200000.0  -429901100000.0
# RepaymentOfDebt                         -343759100000.0  -364736400000.0
# IssuanceOfDebt                           946898100000.0   747840400000.0
# IssuanceOfCapitalStock                    93643800000.0     1581200000.0
# CapitalExpenditure                       -10377800000.0    -8783200000.0
# EndCashPosition                           40345100000.0    15507500000.0
# OtherCashAdjustmentOutsideChangeinCash              NaN         500000.0
# BeginningCashPosition                     15507500000.0    33814400000.0
# ChangesInCash                             24837600000.0   -18306900000.0
# FinancingCashFlow                        824150800000.0   506750100000.0
# NetOtherFinancingCharges                 147599300000.0   135569200000.0
# CashDividendsPaid                        -18145800000.0   -12068600000.0
# CommonStockDividendPaid                  -18145800000.0   -12068600000.0
# NetCommonStockIssuance                    93643800000.0     1581200000.0
# CommonStockIssuance                       93643800000.0     1581200000.0
# NetIssuancePaymentsOfDebt                603139000000.0   383104000000.0
# NetShortTermDebtIssuance                 220235000000.0    79236600000.0
# ShortTermDebtIssuance                    220235000000.0    79236600000.0
# NetLongTermDebtIssuance                  382904000000.0   303867400000.0
# LongTermDebtPayments                    -343759100000.0  -364736400000.0
# LongTermDebtIssuance                     726663100000.0   668603800000.0
# InvestingCashFlow                        -71711800000.0  -103939100000.0
# InterestReceivedCFI                        9439900000.0     6067100000.0
# DividendsReceivedCFI                                NaN              NaN
# NetInvestmentPurchaseAndSale             -68488100000.0  -100493700000.0
# SaleOfInvestment                        1344463400000.0  3083608100000.0
# PurchaseOfInvestment                   -1412951500000.0 -3184101800000.0
# NetBusinessPurchaseAndSale                -2674700000.0     -927400000.0
# PurchaseOfBusiness                        -2674700000.0     -927400000.0
# NetIntangiblesPurchaseAndSale             -4341600000.0    -3924400000.0
# PurchaseOfIntangibles                     -4341600000.0    -3924400000.0
# NetPPEPurchaseAndSale                     -5647300000.0    -4660700000.0
# SaleOfPPE                                   388900000.0      198100000.0
# PurchaseOfPPE                             -6036200000.0    -4858800000.0
# OperatingCashFlow                       -727601400000.0  -421117900000.0
# TaxesRefundPaid                          -50979900000.0   -39721800000.0
# InterestReceivedCFO                      458535300000.0   350328400000.0
# InterestPaidCFO                         -170440400000.0  -131073800000.0
# ChangeInWorkingCapital                  -915044700000.0  -562262700000.0
# ChangeInOtherCurrentLiabilities            1421600000.0    -1810900000.0
# ChangeInOtherCurrentAssets                 -584600000.0      559200000.0
# ChangeInPayable                            7371700000.0     5786200000.0
# ChangeInReceivables                       -4575400000.0     -934300000.0
# OtherNonCashItems                       -296452100000.0  -230500300000.0
# StockBasedCompensation                     2682300000.0     2244100000.0
# ProvisionandWriteOffofAssets              46307000000.0    31896500000.0
# DepreciationAndAmortization                6833200000.0     4853800000.0
# AmortizationCashFlow                       2099300000.0     1420200000.0
# Depreciation                               4733900000.0     3433600000.0
# GainLossOnInvestmentSecurities            -3082900000.0    -3343200000.0
# GainLossOnSaleOfPPE                         125400000.0      133300000.0
# NetIncomeFromContinuingOperations        193095700000.0   155278600000.0
#
#                                              2022-03-31       2021-03-31
# FreeCashFlow                            -377240700000.0   -11167600000.0
# RepaymentOfDebt                         -184356100000.0   -55942900000.0
# IssuanceOfDebt                           417909700000.0    49371400000.0
# IssuanceOfCapitalStock                     1729000000.0     1032100000.0
# CapitalExpenditure                        -6341700000.0    -3094900000.0
# EndCashPosition                           33814400000.0    18493300000.0
# OtherCashAdjustmentOutsideChangeinCash              NaN              NaN
# BeginningCashPosition                     18493300000.0    13445200000.0
# ChangesInCash                             15321100000.0     5048100000.0
# FinancingCashFlow                        322752200000.0    17406300000.0
# NetOtherFinancingCharges                  47836800000.0    41727500000.0
# CashDividendsPaid                         -6026300000.0      -27400000.0
# CommonStockDividendPaid                   -6026300000.0      -27400000.0
# NetCommonStockIssuance                     1729000000.0     1032100000.0
# CommonStockIssuance                        1729000000.0     1032100000.0
# NetIssuancePaymentsOfDebt                280271600000.0   -24457500000.0
# NetShortTermDebtIssuance                  46718000000.0    31485400000.0
# ShortTermDebtIssuance                               NaN              NaN
# NetLongTermDebtIssuance                  233553600000.0   -55942900000.0
# LongTermDebtPayments                    -184356100000.0   -55942900000.0
# LongTermDebtIssuance                     417909700000.0    49371400000.0
# InvestingCashFlow                         63467900000.0    -4285500000.0
# InterestReceivedCFI                        4005800000.0     2267000000.0
# DividendsReceivedCFI                                NaN              0.0
# NetInvestmentPurchaseAndSale              65612400000.0    -3571500000.0
# SaleOfInvestment                        2477421300000.0  2412287500000.0
# PurchaseOfInvestment                   -2411808900000.0 -2415859000000.0
# NetBusinessPurchaseAndSale                          0.0              NaN
# PurchaseOfBusiness                                  NaN              NaN
# NetIntangiblesPurchaseAndSale             -2586200000.0    -1707600000.0
# PurchaseOfIntangibles                     -2586200000.0    -1707600000.0
# NetPPEPurchaseAndSale                     -3564100000.0    -1273400000.0
# SaleOfPPE                                   191400000.0      113900000.0
# PurchaseOfPPE                             -3755500000.0    -1387300000.0
# OperatingCashFlow                       -370899000000.0    -8072700000.0
# TaxesRefundPaid                          -25861000000.0   -14823100000.0
# InterestReceivedCFO                      276273600000.0   213422400000.0
# InterestPaidCFO                          -90026500000.0   -90254900000.0
# ChangeInWorkingCapital                  -501758700000.0   -94949400000.0
# ChangeInOtherCurrentLiabilities            1142100000.0      120000000.0
# ChangeInOtherCurrentAssets                 -234800000.0     -111300000.0
# ChangeInPayable                            4138900000.0     1382900000.0
# ChangeInReceivables                       -3209300000.0      459500000.0
# OtherNonCashItems                       -175985000000.0  -140469100000.0
# StockBasedCompensation                     1612300000.0     1247500000.0
# ProvisionandWriteOffofAssets              48034000000.0    59685800000.0
# DepreciationAndAmortization                3845700000.0     3252700000.0
# AmortizationCashFlow                        968800000.0              NaN
# Depreciation                               2876900000.0     3252700000.0
# GainLossOnInvestmentSecurities            -3277300000.0    -5912200000.0
# GainLossOnSaleOfPPE                         248400000.0       68500000.0
# NetIncomeFromContinuingOperations         95037800000.0    59922600000.0

# %%
#Retrieve Financial Analysis Recommendations
Bajaj_finance.recommendations
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m          6   18     3     3           2
# 1    -1m          6   18     3     3           2
# 2    -2m          6   18     3     3           2
# 3    -3m          6   18     3     3           2

# %%
# Dividend history
Bajaj_finance.get_dividends()
# Out:
# Date
# 2003-07-10 00:00:00+05:30     0.437212
# 2004-07-15 00:00:00+05:30     0.582949
# 2005-06-29 00:00:00+05:30     0.728686
# 2006-06-29 00:00:00+05:30     0.388632
# 2007-06-28 00:00:00+05:30     0.291474
# 2008-06-27 00:00:00+05:30     0.097158
# 2009-06-29 00:00:00+05:30     0.194316
# 2010-07-08 00:00:00+05:30     0.582949
# 2011-06-29 00:00:00+05:30     0.971581
# 2012-07-05 00:00:00+05:30     1.165897
# 2013-07-04 00:00:00+05:30     1.500000
# 2014-07-03 00:00:00+05:30     1.600000
# 2015-07-09 00:00:00+05:30     1.800000
# 2016-03-16 00:00:00+05:30     1.800000
# 2016-07-14 00:00:00+05:30     0.700000
# 2017-07-06 00:00:00+05:30     3.600000
# 2018-07-05 00:00:00+05:30     4.000000
# 2019-07-11 00:00:00+05:30     6.000000
# 2020-03-03 00:00:00+05:30    10.000000
# 2021-07-08 00:00:00+05:30    10.000000
# 2022-06-30 00:00:00+05:30    20.000000
# 2023-06-30 00:00:00+05:30    30.000000
# 2024-06-21 00:00:00+05:30    36.000000
# Name: Dividends, dtype: float64

# %%
# Analyst Price target
Bajaj_finance.get_analyst_price_targets()
# Out:
# {'current': 8914.0,
#  'high': 11000.0,
#  'low': 6290.0,
#  'mean': 9045.516,
#  'median': 9100.0}

# %% [markdown]
# **get the info of the stock and the company**

# %%
Bajaj_finance.info
# Out:
# {'address1': 'Panchshil Tech Park',
#  'address2': '3rd Floor Viman Nagar',
#  'city': 'Pune',
#  'zip': '411014',
#  'country': 'India',
#  'phone': '91 20 7157 6403',
#  'fax': '91 20 7157 6364',
#  'website': 'https://www.aboutbajajfinserv.com/finance-about-us',
#  'industry': 'Credit Services',
#  'industryKey': 'credit-services',
#  'industryDisp': 'Credit Services',
#  'sector': 'Financial Services',
#  'sectorKey': 'financial-services',
#  'sectorDisp': 'Financial Services',
#  'longBusinessSummary': 'Bajaj Finance Limited operates as a deposit-taking non-banking financial company in India. The company offers consumer finance products comprising durable, lifestyle, and digital products; EMI cards; two and three-wheeler, and personal loans; loans against fixed deposit; home and gold loans; and extended warranties, retail EMIs, consumer electronics, furniture, e-commerce, and co-branded credit cards and wallets. It also provides secured and unsecured loans to micro, small, and medium enterprises (MSMEs) and SMEs; loans against property, mutual funds, insurance policies, and shares; lease rental discounting, business and professional loans, working capital loans, and term loans; developer finance; and new and used car, and tractor financing. In addition, the company offer commercial and rural lending; public and corporate deposits; loans against securities; and various investment services, including demat services, broking, and margin trade financing. Further, it distributes life, health, and general insurance products. The company was formerly known as Bajaj Auto Finance Limited and changed its name to Bajaj Finance Limited in September 2010. The company was incorporated in 1987 and is based in Pune, India. Bajaj Finance Limited is a subsidiary of Bajaj Finserv Ltd.',
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Sandeep Vijay Kumar Jain',
#    'title': 'CFO & COO',
#    'fiscalYear': 2023,
#    'totalPay': 62407471,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Deepak  Bagati',
#    'title': 'President of Debt Management Services & COO',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Anurag  Chottani',
#    'title': 'CTO & COO',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Anupam Krishna Sirbhaiya',
#    'title': 'Chief Human Resources & Administrative Officer',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Ramachandran  Vijay',
#    'title': 'Company Secretary & Compliance Officer',
#    'fiscalYear': 2023,
#    'totalPay': 10259894,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Babu  Rao',
#    'title': 'General Counsel',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Deepak Kumar Gupta Reddy',
#    'age': 58,
#    'title': 'President of Rural Lending, Gold Loans & Insurance Businesses',
#    'yearBorn': 1966,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Kurush Homi Irani',
#    'title': 'President of Credit Operations, Customer Experience & Wallets Business',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Fakhari  Sarjan',
#    'title': 'Chief Risk Officer',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Prashant  Verma',
#    'title': 'Chief Information Security Officer',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 7,
#  'boardRisk': 4,
#  'compensationRisk': 4,
#  'shareHolderRightsRisk': 8,
#  'overallRisk': 3,
#  'governanceEpochDate': 1743465600,
#  'compensationAsOfEpochDate': 1703980800,
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 8735.8,
#  'open': 8825.05,
#  'dayLow': 8810.7,
#  'dayHigh': 8973.5,
#  'regularMarketPreviousClose': 8735.8,
#  'regularMarketOpen': 8825.05,
#  'regularMarketDayLow': 8810.7,
#  'regularMarketDayHigh': 8973.5,
#  'dividendRate': 36.0,
#  'dividendYield': 0.41,
#  'exDividendDate': 1718928000,
#  'payoutRatio': 0.1396,
#  'fiveYearAvgDividendYield': 0.24,
#  'beta': 0.717,
#  'trailingPE': 34.58791,
#  'volume': 755419,
#  'regularMarketVolume': 755419,
#  'averageVolume': 1315814,
#  'averageVolume10days': 1341090,
#  'averageDailyVolume10Day': 1341090,
#  'bid': 8913.0,
#  'ask': 8916.3,
#  'bidSize': 0,
#  'askSize': 0,
#  'marketCap': 5537266663424,
#  'fiftyTwoWeekLow': 6375.7,
#  'fiftyTwoWeekHigh': 9260.05,
#  'priceToSalesTrailing12Months': 15.465032,
#  'fiftyDayAverage': 8540.334,
#  'twoHundredDayAverage': 7407.646,
#  'trailingAnnualDividendRate': 36.0,
#  'trailingAnnualDividendYield': 0.0041209734,
#  'currency': 'INR',
#  'tradeable': False,
#  'enterpriseValue': 7881261842432,
#  'forwardPE': 26.279675,
#  'profitMargins': 0.44638002,
#  'floatShares': 260164865,
#  'sharesOutstanding': 621212032,
#  'heldPercentInsiders': 0.54906,
#  'heldPercentInstitutions': 0.25211,
#  'impliedSharesOutstanding': 632294016,
#  'bookValue': 1403.263,
#  'priceToBook': 6.3520885,
#  'lastFiscalYearEnd': 1711843200,
#  'nextFiscalYearEnd': 1743379200,
#  'mostRecentQuarter': 1735603200,
#  'earningsQuarterlyGrowth': 0.167,
#  'netIncomeToCommon': 159827804160,
#  'trailingEps': 257.71,
#  'lastSplitFactor': '5:1',
#  'lastSplitDate': 1473292800,
#  'enterpriseToRevenue': 22.012,
#  '52WeekChange': 0.20834625,
#  'SandP52WeekChange': 0.028231144,
#  'lastDividendValue': 36.0,
#  'lastDividendDate': 1718928000,
#  'quoteType': 'EQUITY',
#  'currentPrice': 8913.65,
#  'targetHighPrice': 11000.0,
#  'targetLowPrice': 6290.0,
#  'targetMeanPrice': 9045.516,
#  'targetMedianPrice': 9100.0,
#  'recommendationMean': 1.9375,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 33,
#  'totalCash': 124034998272,
#  'totalCashPerShare': 200.166,
#  'totalDebt': 2581427650560,
#  'totalRevenue': 358050791424,
#  'debtToEquity': 290.321,
#  'revenuePerShare': 579.099,
#  'grossProfits': 334166491136,
#  'earningsGrowth': 0.157,
#  'revenueGrowth': 0.196,
#  'grossMargins': 0.93329,
#  'ebitdaMargins': 0.0,
#  'operatingMargins': 0.59841996,
#  'financialCurrency': 'INR',
#  'symbol': 'BAJFINANCE.NS',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Free Realtime Quote',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'regularMarketChangePercent': 2.0358007,
#  'regularMarketPrice': 8913.65,
#  'shortName': 'BAJAJ FINANCE LIMITED',
#  'corporateActions': [],
#  'regularMarketTime': 1744361994,
#  'exchange': 'NSI',
#  'messageBoardId': 'finmb_881576',
#  'exchangeTimezoneName': 'Asia/Kolkata',
#  'exchangeTimezoneShortName': 'IST',
#  'gmtOffSetMilliseconds': 19800000,
#  'market': 'in_market',
#  'esgPopulated': False,
#  'hasPrePostMarketData': False,
#  'firstTradeDateMilliseconds': 1025495100000,
#  'regularMarketChange': 177.85059,
#  'regularMarketDayRange': '8810.7 - 8973.5',
#  'fullExchangeName': 'NSE',
#  'averageDailyVolume3Month': 1315814,
#  'fiftyTwoWeekLowChange': 2537.9502,
#  'fiftyTwoWeekLowChangePercent': 0.3980661,
#  'fiftyTwoWeekRange': '6375.7 - 9260.05',
#  'fiftyTwoWeekHighChange': -346.3994,
#  'fiftyTwoWeekHighChangePercent': -0.037407942,
#  'fiftyTwoWeekChangePercent': 20.834625,
#  'earningsTimestamp': 1745924340,
#  'earningsTimestampStart': 1745924340,
#  'earningsTimestampEnd': 1745924340,
#  'earningsCallTimestampStart': 1738155600,
#  'earningsCallTimestampEnd': 1738155600,
#  'isEarningsDateEstimate': False,
#  'epsTrailingTwelveMonths': 257.71,
#  'epsCurrentYear': 270.27,
#  'priceEpsCurrentYear': 32.98054,
#  'fiftyDayAverageChange': 373.3164,
#  'fiftyDayAverageChangePercent': 0.043712154,
#  'twoHundredDayAverageChange': 1506.0044,
#  'twoHundredDayAverageChangePercent': 0.20330405,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 15,
#  'averageAnalystRating': '1.9 - Buy',
#  'cryptoTradeable': False,
#  'marketState': 'REGULAR',
#  'longName': 'Bajaj Finance Limited',
#  'trailingPegRatio': None}

# %% [markdown]
# **Ratios of the stock**

# %%
# PE, Book value, PB, ROE, ROCE, Debt-to-Equity, Dividend Yield,  Price-to-Sales (P/S) Ratio,   Net Profit Margin for the stock

# Get Financial data of the stock
bajaj_finance = yf.Ticker('BAJFINANCE.NS')

# Get financials and balance sheet
financials = bajaj_finance.financials
balance_sheet = bajaj_finance.balance_sheet

# Accessing info dictionary for relevant data
info = bajaj_finance.info

print('------------------------------------------------')
# Extracting financial metrics
try:
  pe_ratio = info['trailingPE']
  print(f"P/E Ratio: {pe_ratio}")
except KeyError:
  print("P/E Ratio not found.")

try:
  book_value = info['bookValue']
  print(f"Book Value: {book_value}")
except KeyError:
  print("Book Value not found.")

try:
  pb_ratio = info['priceToBook']
  print(f"P/B Ratio: {pb_ratio}")
except KeyError:
  print("P/B Ratio not found.")

try:
  # Extract latest Net Income and Interest Expense (from Income Statement)
  net_income = financials.loc['Net Income'].iloc[0]
  interest_expense = financials.loc['Interest Expense'].iloc[0]

  # # Extract latest Total Shareholder Equity and Total Assets/Liabilities (from Balance Sheet)
  shareholder_equity = balance_sheet.loc['Stockholders Equity'].iloc[0]
  total_assets = balance_sheet.loc['Total Assets'].iloc[0]
  total_liabilities = balance_sheet.loc['Total Debt'].iloc[0]
  # Calculate ROE = Net Income / Shareholder's Equity
  roe = (net_income / shareholder_equity) * 100
  print(f"ROE: {roe}")
except KeyError:
  print("ROE not found.")

try:
  ebit = net_income + interest_expense
  capital_employed = total_assets - total_liabilities
  roce = (ebit / capital_employed) * 100
  print(f"ROCE: {roce}")
except KeyError:
  print("ROCE not found.")


try:
  debt_to_equity = info['debtToEquity']
  print(f"Debt-to-Equity: {debt_to_equity}")
except KeyError:
    print("Debt-to-Equity not found.")



try:
  dividend_yield = info['dividendYield']
  print(f"Dividend Yield: {dividend_yield}")
except KeyError:
  print("Dividend Yield not found.")


try:
  ps_ratio = info['priceToSalesTrailing12Months']
  print(f"Price-to-Sales (P/S) Ratio: {ps_ratio}")
except KeyError:
  print("Price-to-Sales (P/S) Ratio not found")


try:
  net_profit_margin = info['profitMargins']
  print(f"Net Profit Margin: {net_profit_margin}")
except KeyError:
  print("Net Profit Margin not found.")
# Out:
# ------------------------------------------------
# P/E Ratio: 34.581894
# Book Value: 1403.263
# P/B Ratio: 6.3509836
# ROE: 18.84230269501345
# ROCE: 21.090215404504296
# Debt-to-Equity: 290.321
# Dividend Yield: 0.41
# Price-to-Sales (P/S) Ratio: 15.462341
# Net Profit Margin: 0.44638002

# %%
# Parameters
stock_ticker = "BAJFINANCE.NS"
benchmark_ticker = "^NSEI"  # Nifty 50 Index
risk_free_rate = 0.06  # 6% annual

# Get 1 year of historical daily data
end = datetime.now()
start = end - timedelta(days=365)

# Download data
stock_data = yf.download(stock_ticker, start=start, end=end)
benchmark_data = yf.download(benchmark_ticker, start=start, end=end)

# Calculate daily returns
stock_returns = stock_data['Close'].pct_change().dropna()
benchmark_returns = benchmark_data['Close'].pct_change().dropna()

combined_returns = pd.concat([stock_returns, benchmark_returns], axis=1)
combined_returns.columns = ['Stock', 'Benchmark']
combined_returns.dropna(inplace=True)
combined_returns.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                Stock  Benchmark
# Date
# 2024-04-15 -0.021205  -0.010964
# 2024-04-16 -0.017241  -0.005594
# 2024-04-18 -0.008779  -0.006865
# 2024-04-19  0.032829   0.006872
# 2024-04-22  0.024257   0.008552

# %%
# Beta & Alpha (using linear regression)
cov_matrix = np.cov(combined_returns['Stock'], combined_returns['Benchmark'])
beta = cov_matrix[0, 1] / cov_matrix[1, 1]
alpha = combined_returns['Stock'].mean() - beta * combined_returns['Benchmark'].mean()

print(f"Alpha: {alpha:.4f}")
print(f"Beta: {beta:.4f}")
# Out:
# Alpha: 0.0009
# Beta: 1.1054

# %%
# Average daily return and volatility
avg_daily_return = combined_returns['Stock'].mean()
daily_volatility = combined_returns['Stock'].std()

# Annualized return and volatility
trading_days = 252
annual_return = avg_daily_return * trading_days
annual_volatility = daily_volatility * np.sqrt(trading_days)

# Sharpe Ratio
sharpe_ratio = (annual_return - risk_free_rate) / annual_volatility


print(f"Average Daily Return: {avg_daily_return:.4%}")
print(f"Annualized Return: {annual_return:.2%}")
print(f"Annualized Volatility: {annual_volatility:.2%}")
print(f"Sharpe Ratio: {sharpe_ratio:.2f}")
# Out:
# Average Daily Return: 0.0880%
# Annualized Return: 22.17%
# Annualized Volatility: 27.14%
# Sharpe Ratio: 0.60
